# %%
import pandas as pd

# %%
df = pd.read_csv("../data/student_depression_dataset.csv", sep=",")
df.head(3)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 0                                   Yes               3.0              1.0
# 1                                    No               3.0              2.0
# ...

# %%
df2 = df.sort_values(by="Age", ascending=True) #Ordenando de forma crescete pela idade
#OBS. Posso utilizar a flag "inplacing=True" para ja sobrescrever o dataframe, sem necessidade de salvar como um novo (df2)
df2.head(3)
# Out:
#            id  Gender   Age     City Profession  Academic Pressure  \
# 3212    16161    Male  18.0  Lucknow    Student                1.0
# 26320  132740  Female  18.0   Rajkot    Student                5.0
# 26318  132733    Male  18.0    Surat    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3212             0.0  8.96                 3.0               0.0
# 26320            0.0  8.91                 3.0               0.0
# 26318            0.0  7.83                 5.0               0.0
#
#             Sleep Duration Dietary Habits      Degree  \
# 3212           '7-8 hours'      Unhealthy  'Class 12'
# 26320          '5-6 hours'      Unhealthy  'Class 12'
# 26318  'More than 8 hours'       Moderate  'Class 12'
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 3212                                     No               0.0
# 26320                                   Yes              10.0
# ...

# %%
df2 = df.sort_values(by=["Age", "City"], ascending=[True, False])
df2.head(3)
# Out:
#         id Gender   Age           City Profession  Academic Pressure  \
# 31     232   Male  18.0  Visakhapatnam    Student                2.0
# 1697  8723   Male  18.0  Visakhapatnam    Student                2.0
# 1827  9414   Male  18.0  Visakhapatnam    Student                2.0
#
#       Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 31              0.0  6.21                 3.0               0.0
# 1697            0.0  8.70                 5.0               0.0
# 1827            0.0  5.32                 3.0               0.0
#
#            Sleep Duration Dietary Habits      Degree  \
# 31            '5-6 hours'      Unhealthy  'Class 12'
# 1697          '7-8 hours'       Moderate  'Class 12'
# 1827  'Less than 5 hours'      Unhealthy  'Class 12'
#
#      Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 31                                     Yes               4.0              2.0
# ...

# %%
import pandas as pd

# %%
# Parquet é um arquivo que facilita a leitura e reduz o armazenamento
df = pd.read_parquet("../data/0000.parquet")

# %%
df
# Out:
#                                                   output  \
# 0      ```python\ntasks = []\nwhile True:\n    task =...
# 1      ```python\nshopping_list = {}\nwhile True:\n  ...
# 2      ```python\ntotal_time = 0\nfor i in range(1, 8...
# 3      ```python\ntotal_bill = float(input('Enter the...
# 4      ```python\nmovie_list = {}\nwhile True:\n    g...
# ...                                                  ...
# 49621  c.execute('''CREATE TABLE IF NOT EXISTS stocks...
# 49622  c.execute("INSERT INTO stocks VALUES ('2023-09...
# 49623  c.execute('SELECT * FROM stocks WHERE symbol=?...
# 49624  c.execute('UPDATE stocks SET qty=120 WHERE sym...
# 49625  ```python\nimport requests\n\nurl = 'https://w...
#
#                                                     text  \
# 0      Help me set up my daily to-do list! Setting up...
# 1      Create a shopping list based on my inputs! Cre...
# 2      Calculate how much time I spend on my phone pe...
# ...

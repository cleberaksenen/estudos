# %%
import pandas as pd

# %%
df = pd.read_csv("../data/student_depression_dataset.csv", sep=",")
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
#Mostra linhas e colunas
df.shape
# Out:
# (27901, 18)

# %%
#Mostra outras informações
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
#Estatística da coluna "Patient age"
df["Age"].describe()
# Out:
# count    27901.000000
# mean        25.822300
# std          4.905687
# min         18.000000
# 25%         21.000000
# 50%         25.000000
# 75%         30.000000
# max         59.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### Posso realizar operações escalares e vetoriais com as séries

# %%
df["Age_new"] = df["Age"] + 1

# %%
df["Age"].head(3)
# Out:
# 0    33.0
# 1    24.0
# 2    31.0
# Name: Age, dtype: float64

# %%
df["Age_new"].head(3)
# Out:
# 0    34.0
# 1    25.0
# 2    32.0
# Name: Age_new, dtype: float64

# %% [markdown]
# ### É possível fazer comparações lógicas também

# %%
df["Age_new"] < 30
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 27896     True
# 27897     True
# 27898    False
# 27899     True
# 27900     True
# Name: Age_new, Length: 27901, dtype: bool

# %%
condicao = df["Age"] <= 18
df[condicao] # Retorna apenas o que é VERDADEIRO
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 24        173    Male  18.0      Bangalore    Student                4.0
# 30        222    Male  18.0          Surat    Student                4.0
# 31        232    Male  18.0  Visakhapatnam    Student                2.0
# 52        324  Female  18.0       Vadodara    Student                3.0
# 72        421    Male  18.0         Bhopal    Student                3.0
# ...       ...     ...   ...            ...        ...                ...
# 27823  140235    Male  18.0      Ahmedabad    Student                2.0
# 27858  140438  Female  18.0       Ludhiana    Student                3.0
# 27867  140504    Male  18.0      Ahmedabad    Student                3.0
# 27884  140594    Male  18.0         Meerut    Student                5.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
# É recomendado sempre fazer uma cópia do dataframe original
condicao = (df["Age"] > 18) & (df["Age"] < 22)
df2 = df[condicao].copy() #Cópia do df original com o filtro
df2
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 13        100  Female  19.0     Rajkot    Student                2.0
# 14        103  Female  19.0     Kalyan    Student                5.0
# 17        132  Female  20.0  Ahmedabad    Student                5.0
# 18        139    Male  19.0    Chennai    Student                2.0
# 25        176  Female  20.0     Mumbai    Student                5.0
# ...       ...     ...   ...        ...        ...                ...
# 27877  140545    Male  19.0       Pune    Student                2.0
# 27879  140548    Male  21.0     Kalyan    Student                1.0
# 27885  140597  Female  19.0     Mumbai    Student                2.0
# 27888  140630    Male  19.0    Kolkata    Student                4.0
# 27892  140669  Female  20.0     Indore    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 13               0.0  8.52                 4.0               0.0
# ...

# %% [markdown]
# ### Andando pelas colunas

# %%
df2["City"] #Isso aqui é uma lista!
# Out:
# 13          Rajkot
# 14          Kalyan
# 17       Ahmedabad
# 18         Chennai
# 25          Mumbai
#            ...
# 27877         Pune
# 27879       Kalyan
# 27885       Mumbai
# 27888      Kolkata
# 27892       Indore
# Name: City, Length: 5523, dtype: object

# %%
df2[["City"]] #Isso aqui é um Dataframe!
# Out:
#             City
# 13        Rajkot
# 14        Kalyan
# 17     Ahmedabad
# 18       Chennai
# 25        Mumbai
# ...          ...
# 27877       Pune
# 27879     Kalyan
# 27885     Mumbai
# 27888    Kolkata
# 27892     Indore
#
# [5523 rows x 1 columns]

# %%
df2[["City", "Profession"]] #Selecionando mais de uma coluna
# Out:
#             City Profession
# 13        Rajkot    Student
# 14        Kalyan    Student
# 17     Ahmedabad    Student
# 18       Chennai    Student
# 25        Mumbai    Student
# ...          ...        ...
# 27877       Pune    Student
# 27879     Kalyan    Student
# 27885     Mumbai    Student
# 27888    Kolkata    Student
# 27892     Indore    Student
#
# [5523 rows x 2 columns]

# %%
# Renomeando colunas
df2.rename(columns = {"City": "Cidade", 
                      "Profession": "Profissao"}) # Foi renomeado, mas não salvo no df2
                                                  # O rename gera um dataframe novo
# Out:
#            id  Gender   Age     Cidade Profissao  Academic Pressure  \
# 13        100  Female  19.0     Rajkot   Student                2.0
# 14        103  Female  19.0     Kalyan   Student                5.0
# 17        132  Female  20.0  Ahmedabad   Student                5.0
# 18        139    Male  19.0    Chennai   Student                2.0
# 25        176  Female  20.0     Mumbai   Student                5.0
# ...       ...     ...   ...        ...       ...                ...
# 27877  140545    Male  19.0       Pune   Student                2.0
# 27879  140548    Male  21.0     Kalyan   Student                1.0
# 27885  140597  Female  19.0     Mumbai   Student                2.0
# 27888  140630    Male  19.0    Kolkata   Student                4.0
# 27892  140669  Female  20.0     Indore   Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 13               0.0  8.52                 4.0               0.0
# ...

# %%
#Para de fato renomear o dataframe, precisa-se atribuir a ele mesmo
df2 = df2.rename(columns = {"City": "Cidade", 
                            "Profession": "Profissao"})
df2
# Out:
#            id  Gender   Age     Cidade Profissao  Academic Pressure  \
# 13        100  Female  19.0     Rajkot   Student                2.0
# 14        103  Female  19.0     Kalyan   Student                5.0
# 17        132  Female  20.0  Ahmedabad   Student                5.0
# 18        139    Male  19.0    Chennai   Student                2.0
# 25        176  Female  20.0     Mumbai   Student                5.0
# ...       ...     ...   ...        ...       ...                ...
# 27877  140545    Male  19.0       Pune   Student                2.0
# 27879  140548    Male  21.0     Kalyan   Student                1.0
# 27885  140597  Female  19.0     Mumbai   Student                2.0
# 27888  140630    Male  19.0    Kolkata   Student                4.0
# 27892  140669  Female  20.0     Indore   Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 13               0.0  8.52                 4.0               0.0
# ...

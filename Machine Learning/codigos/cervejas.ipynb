# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import tree

# %%
cervejas = pd.read_excel("./data/dados_cerveja.xlsx")

# %%
cervejas = cervejas.replace({'mud': 0, 'pint': 1,
                             'não': 0, 'sim': 1,
                             'escura': 0, 'clara': 1})
# Out:
# C:\Users\clebe\AppData\Local\Temp\ipykernel_848\3700312731.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cervejas = cervejas.replace({'mud': 0, 'pint': 1,

# %%
cervejas
# Out:
#     id  temperatura  copo  espuma  cor     classe
# 0    1           -5     0       0    0  weissbier
# 1    2           -5     0       1    0  weissbier
# 2    3           -1     1       0    1  weissbier
# 3    4           -1     1       1    1  weissbier
# 4    5           -5     1       0    0   pale-ale
# 5    6           -5     1       0    1   pale-ale
# 6    7           -5     1       1    0   pale-ale
# 7    8           -1     0       0    1     pilsen
# 8    9           -5     0       0    1     pilsen
# 9   10           -1     0       1    1     pilsen
# 10  11           -1     0       0    0     pilsen
# 11  12           -1     0       1    0     pilsen

# %%
cervejas['classe'].unique()
# Out:
# array(['weissbier', 'pale-ale', 'pilsen'], dtype=object)

# %%
features = ['temperatura', 'copo', 'espuma', 'cor']

X = cervejas[features]
y = cervejas['classe']

# %%
model = tree.DecisionTreeClassifier()

model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
plt.figure(dpi=600)

tree.plot_tree(model,
               feature_names=X.columns,
               class_names=sorted(y.unique().astype(str)),
               filled=True)
# Out:
# [Text(0.5555555555555556, 0.875, 'copo <= 0.5\ngini = 0.653\nsamples = 12\nvalue = [3, 5, 4]\nclass = pilsen'),
#  Text(0.3333333333333333, 0.625, 'temperatura <= -3.0\ngini = 0.408\nsamples = 7\nvalue = [0, 5, 2]\nclass = pilsen'),
#  Text(0.4444444444444444, 0.75, 'True  '),
#  Text(0.2222222222222222, 0.375, 'cor <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = weissbier'),
#  Text(0.1111111111111111, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = weissbier'),
#  Text(0.3333333333333333, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = pilsen'),
#  Text(0.4444444444444444, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]\nclass = pilsen'),
#  Text(0.7777777777777778, 0.625, 'temperatura <= -3.0\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 2]\nclass = pale-ale'),
#  Text(0.6666666666666667, 0.75, '  False'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]\nclass = pale-ale'),
#  Text(0.8888888888888888, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = weissbier')]
